# %% [markdown]
# * 2

# %%
print ("Hello Everyone !!!")
# Out:
# Hello Everyone !!!

# %%
print ("Hello \n World")
# Out:
# Hello
#  World

# %%
print ("Hello")
print ("World")
# Out:
# Hello
# World

# %%
print ("'Rohit's date of birth is 12/05/1999 '")
# Out:
# 'Rohit's date of birth is 12/05/1999 '

# %% [markdown]
# * 3

# %%
x = "Hello"
print (x)
# Out:
# Hello

# %% [markdown]
# * 4

# %%
num = 25
print("Integer:", num)


pi = 3.14
print("Float:", pi)


name = "Sandeep"
print("String:", name)


is_student = True
print("Boolean:", is_student)


fruits = ["Apple", "Banana", "Mango"]
print("List:", fruits)


coordinates = (10, 20)
print("Tuple:", coordinates)


unique_numbers = {1, 2, 3, 4}
print("Set:", unique_numbers)


student = {"name": "Rohit", "age": 20, "course": "BCA"}
print("Dictionary:", student)
# Out:
# Integer: 25
# Float: 3.14
# String: Sandeep
# Boolean: True
# List: ['Apple', 'Banana', 'Mango']
# Tuple: (10, 20)
# Set: {1, 2, 3, 4}
# Dictionary: {'name': 'Rohit', 'age': 20, 'course': 'BCA'}

# %% [markdown]
# * 5

# %%
a = "Sandeep"
b = "Sabharwal"
full_name = a + " " + b
print("Full Name:", full_name)
# Out:
# Full Name: Sandeep Sabharwal

# %% [markdown]
# * 6

# %%
a = "Sandeep"
b = "Sabharwal"
c = "(Keshav)"
d = a + " " + c + " " + b
print("Full Name:", d)
# Out:
# Full Name: Sandeep (Keshav) Sabharwal

# %%
name = "Sandeep Sabharwal"
sapid = 590024429
date_of_birth = "18 mar 2007"
address = "UPES\n \tBidholi Campus\n \tPincode: 248007"
programme = "AI & ML"
semester = 2 

print("Name:", name)
print("SAP ID:", sapid)
print("Date of Birth:", date_of_birth)
print("Address:", address)
print("Programme:", programme)
print("Semester:", semester)
# Out:
# Name: Sandeep Sabharwal
# SAP ID: 590024429
# Date of Birth: 18 mar 2007
# Address: UPES
#  	Bidholi Campus
#  	Pincode: 248007
# Programme: AI & ML
# Semester: 2
