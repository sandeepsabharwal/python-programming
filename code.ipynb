# %% [markdown]
# Q. please explain in simple psenducode how upper() function is not a function method of str codes.
#
# Ans.
# Upper() is inscapulated between str function and is not a universal function.
#
# Psuedocode:
#
# super class string()
#
#  class str()
#
#  function upper()

# %% [markdown]
# ## note
# numpy is the base class and uske changes ko inharit krta hai pandas

# %% [markdown]
# method-> is native to class
#
# (dont have to pass an argument)
#
# #### what is an argument?
#
# In Python, an argument is the actual value you pass into a function when you call it.
