# %% [markdown]
# ## Section A

# %%
items = [("A", 90), ("B", 95), ("C", 95), ("D", 85)]
k = 2
sorted_items = sorted(items,key=lambda x:x[1], reverse=True)
result = sorted_items [ :k]
print (result)
# Out:
# [('B', 95), ('C', 95)]

# %%
pairs = [("sports","win"), ("sports","win"), ("tech","ai")]

def count_by_category(pairs):
    d={}
    for cat, word in pairs:
        d.setdefault(cat, {})
        d[cat].setdefault(word, 0)
        d[cat][word] += 1
    return d
print(count_by_category(pairs))
# Out:
# {'sports': {'win': 2}, 'tech': {'ai': 1}}

# %%
def missing_number(nums):
    n = len(nums)
    total = n * (n + 1) // 2
    return total - sum(nums)
nums = [3, 0, 1]
print(missing_number(nums))
# Out:
# 2

# %%
def add_unique(x, seen = None):
    if seen is None:
        seen = set()
    if x not in seen:
        seen.add(x)
    return list(seen)
print(add_unique(1))
print(add_unique(2))
# Out:
# [1]
# [2]

# %%
def parse(lines):
    parsed_data = []
    for line in lines:
        parts = line.split(",")
        if len(parts) == 3:
            name, age, score = parts
            parsed_data.append(f"{name}:{age}:{score}")
    return parsed_data


lines = [
    "john,25,90",
    "john,25,90",
    "anna,130,70",
    "bob,22,80"
]

print(parse(lines))
# ['john:25:90', 'john:25:90', 'anna:130:70', 'bob:22:80']
# Out:
# ['john:25:90', 'john:25:90', 'anna:130:70', 'bob:22:80']
